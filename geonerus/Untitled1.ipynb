# %%
import time
import requests as r
import json
data=r.get('https://api.vk.com/method/users.getSubscriptions?user_id=1&extended=1&fields=name' ).text
otv={}
f=open('users_likes.txt')
a=eval(f.read()[8:-1])
f.close()
print(type(a))
ids=list(a.keys())
print(len(ids))
for x in ids[5:1006]:
    tmp=[]
    print('sleep')
    time.sleep(0.3)
    data =  json.loads(r.get('https://api.vk.com/method/users.getSubscriptions?user_id='+str(x)+'&extended=1&fields=name' ).text)['response']
    for sub in data:
        try:
            tmp.append(sub['name'])
        except BaseException:
                pass
    otv.update({x:tmp})
    print(len(otv))
# Out:
# <class 'dict'>
# 37995
# sleep
# 1
# sleep
# 2
# sleep
# 3
# sleep
# 4
# sleep
# 5
# sleep
# 6
# sleep
# 7
# sleep
# 8
# sleep
# 9
# sleep
# 10
# sleep
# 11
# sleep
# 12
# sleep
# 13
# sleep
# 14
# sleep
# 15
# sleep
# 16
# sleep
# 17
# sleep
# 18
# sleep
# 19
# sleep
# 20
# sleep
# 21
# sleep
# 22
# sleep
# 23
# sleep
# 24
# sleep
# 25
# sleep
# 26
# sleep
# 27
# sleep
# 28
# sleep
# 29
# sleep
# 30
# sleep
# 31
# sleep
# 32
# sleep
# 33
# sleep
# 34
# sleep
# 35
# sleep
# 36
# sleep
# 37
# sleep
# 38
# sleep
# 39
# sleep
# 40
# sleep
# 41
# sleep
# 42
# sleep
# 43
# sleep
# 44
# sleep
# 45
# sleep
# 46
# sleep
# 47
# sleep
# 48
# sleep
# 49
# sleep
# 50
# sleep
# 51
# sleep
# 52
# sleep
# 53
# sleep
# 54
# sleep
# 55
# sleep
# 56
# sleep
# 57
# sleep
# 58
# sleep
# 59
# sleep
# 60
# sleep
# 61
# sleep
# 62
# sleep
# 63
# sleep
# 64
# sleep
# 65
# sleep
# 66
# sleep
# 67
# sleep
# 68
# sleep
# 69
# sleep
# 70
# sleep
# 71
# sleep
# 72
# sleep
# 73
# sleep
# 74
# sleep
# 75
# sleep
# ...
